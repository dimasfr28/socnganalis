# %%
#@title Twitter Auth Token

twitter_auth_token = '9af842a017f6ecdbf5ff9933b41eec427812f132' # change this auth token

# %%
filename = 'indihome_tweets.csv'
# Scrape tweet hanya dari akun IndiHome
# !npx -y tweet-harvest@2.6.1 -o {filename} -s "from:IndiHome" --token "$twitter_auth_token" --limit 40

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 filename = f'{row["id_str"]}_replies.csv'
#       2 # Gunakan parameter untuk scrape tweet spesifik beserta repliesnya
#       4 get_ipython().system('npx -y tweet-harvest@2.6.1 -o {filename} -s f"conversation_id:{row[\'id_str\']}" --token "$twitter_auth_token" --limit {row[\'reply_count\'] + 10}')
#
# NameError: name 'row' is not defined

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#     conversation_id_str                      created_at  favorite_count  \
# 0   1989677741894246514  Sat Nov 15 23:59:58 +0000 2025               0
# 1   1989677741894246514  Sat Nov 15 20:57:52 +0000 2025               0
# 2   1989677741894246514  Sat Nov 15 20:34:04 +0000 2025               0
# 3   1989677741894246514  Sat Nov 15 23:38:52 +0000 2025               0
# 4   1989677741894246514  Sat Nov 15 13:14:22 +0000 2025               0
# 5   1989677741894246514  Sun Nov 16 00:21:22 +0000 2025               0
# 6   1989677741894246514  Sat Nov 15 14:15:31 +0000 2025               0
# 7   1989677741894246514  Sat Nov 15 20:59:31 +0000 2025               0
# 8   1989677741894246514  Sun Nov 16 00:12:19 +0000 2025               0
# 9   1989677741894246514  Sun Nov 16 00:16:13 +0000 2025               0
# 10  1989677741894246514  Sun Nov 16 00:10:46 +0000 2025               0
# 11  1989677741894246514  Sat Nov 15 22:45:49 +0000 2025               0
# ...

# %%
import pandas as pd

df = pd.read_excel("tweets-data/tweet.xlsx", header=4)
df
# Out:
#         Name                           Profile  \
# 0   IndiHome  https://www.twitter.com/IndiHome
# 1   IndiHome  https://www.twitter.com/IndiHome
# 2   IndiHome  https://www.twitter.com/IndiHome
# 3   IndiHome  https://www.twitter.com/IndiHome
# 4   IndiHome  https://www.twitter.com/IndiHome
# 5   IndiHome  https://www.twitter.com/IndiHome
# 6   IndiHome  https://www.twitter.com/IndiHome
# 7   IndiHome  https://www.twitter.com/IndiHome
# 8   IndiHome  https://www.twitter.com/IndiHome
# 9   IndiHome  https://www.twitter.com/IndiHome
# 10  IndiHome  https://www.twitter.com/IndiHome
# 11  IndiHome  https://www.twitter.com/IndiHome
#
#                                             Permalink          Type  \
# 0   https://www.twitter.com/1075673058931806208/st...        status
# 1   https://www.twitter.com/1075673058931806208/st...         photo
# 2   https://www.twitter.com/1075673058931806208/st...  animated_gif
# 3   https://www.twitter.com/1075673058931806208/st...        status
# ...

# %%
import subprocess
import json
import pandas as pd

# Perintah tweet-harvest (tanpa output ke file)
cmd = [
    "npx", "-y", "tweet-harvest@2.6.1",
    "-s", "conversation_id:1989677741894246514",
    "--token", twitter_auth_token,
    "--limit", "14"
]

# Jalankan dan ambil output JSON Lines
result = subprocess.run(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)

# Parsing JSONL → list of dict
data = []
for line in result.stdout.splitlines():
    try:
        data.append(json.loads(line))
    except:
        pass

# Masukkan ke DataFrame
df = pd.DataFrame(data)

df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
